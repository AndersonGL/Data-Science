# %% [markdown]
# <a href="https://colab.research.google.com/github/AndersonGL/Data-Science/blob/main/udemy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install matplotlib seaborn
# %pip install lxml
# %pip install pandas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('Olá, Mundo!')
# Out:
# Olá, Mundo!

# %%
dados = pd.read_csv('fifa.csv')

dados
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
dados.tail(8)  # puxa os ultimos nomes da tabela
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18199       18199  244677        M. Baldisimo   18
# 18200       18200  231381            J. Young   18
# 18201       18201  243413            D. Walsh   18
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo          Nationality  \
# 18199  https://cdn.sofifa.org/players/4/19/244677.png               Canada
# 18200  https://cdn.sofifa.org/players/4/19/231381.png             Scotland
# 18201  https://cdn.sofifa.org/players/4/19/243413.png  Republic of Ireland
# 18202  https://cdn.sofifa.org/players/4/19/238813.png              England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png               Sweden
# ...

# %%
dados.head(21)   # puxa os primeiros nomes da tabela
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
# 15          15  211110          P. Dybala   24
# 16          16  202126            H. Kane   24
# 17          17  194765       A. Griezmann   27
# 18          18  192448      M. ter Stegen   26
# ...

# %%
dados.columns       # leventa todas colunas
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
dados.index               # verifica as linhas
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %%
dados ['Name']
# Out:
# 0                  L. Messi
# 1         Cristiano Ronaldo
# 2                 Neymar Jr
# 3                    De Gea
# 4              K. De Bruyne
#                 ...
# 18202          J. Lundstram
# 18203    N. Christoffersson
# 18204             B. Worman
# 18205        D. Walker-Rice
# 18206             G. Nugent
# Name: Name, Length: 18207, dtype: object

# %%
dados[['Name', 'Nationality' ,'Wage']]
# Out:
#                      Name Nationality   Wage
# 0                L. Messi   Argentina  €565K
# 1       Cristiano Ronaldo    Portugal  €405K
# 2               Neymar Jr      Brazil  €290K
# 3                  De Gea       Spain  €260K
# 4            K. De Bruyne     Belgium  €355K
# ...                   ...         ...    ...
# 18202        J. Lundstram     England    €1K
# 18203  N. Christoffersson      Sweden    €1K
# 18204           B. Worman     England    €1K
# 18205      D. Walker-Rice     England    €1K
# 18206           G. Nugent     England    €1K
#
# [18207 rows x 3 columns]

# %%
#dados.iloc[2,2]  # seleciona linha e coluna
# Out:
# np.int64(26)

# %%
dados.loc[dados['Nationality'] == 'Brazil']  # puxandos dados somente da nação barasileira'
# Out:
#        Unnamed: 0      ID              Name  Age  \
# 2               2  190871         Neymar Jr   26
# 27             27  200145          Casemiro   26
# 32             32  189242          Coutinho   26
# 35             35  176676           Marcelo   30
# 39             39  164240      Thiago Silva   33
# ...           ...     ...               ...  ...
# 17059       17059  243750  Gianluca Zanette   21
# 17446       17446  235949         Strefezza   21
# 17588       17588  244311     Lucas Ribeiro   19
# 17611       17611  241268   Felipe Ferreyra   20
# 18170       18170  246447   Nicolas Firmino   17
#
#                                                 Photo Nationality  \
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 27     https://cdn.sofifa.org/players/4/19/200145.png      Brazil
# 32     https://cdn.sofifa.org/players/4/19/189242.png      Brazil
# 35     https://cdn.sofifa.org/players/4/19/176676.png      Brazil
# ...

# %%
dados.loc[dados['Age'] == 18 ]   # localizando por idade
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 226           226  235243      M. de Ligt   18
# 1004         1004  233049       J. Sancho   18
# 1800         1800  235883    R. Sessegnon   18
# 2640         2640  241168  G. Chakvetadze   18
# 2725         2725  241461   Ferrán Torres   18
# ...           ...     ...             ...  ...
# 18197       18197  246167      D. Holland   18
# 18198       18198  242844      J. Livesey   18
# 18199       18199  244677    M. Baldisimo   18
# 18200       18200  231381        J. Young   18
# 18201       18201  243413        D. Walsh   18
#
#                                                 Photo          Nationality  \
# 226    https://cdn.sofifa.org/players/4/19/235243.png          Netherlands
# 1004   https://cdn.sofifa.org/players/4/19/233049.png              England
# 1800   https://cdn.sofifa.org/players/4/19/235883.png              England
# 2640   https://cdn.sofifa.org/players/4/19/241168.png              Georgia
# ...

# %%
dados.sort_values('Name')  # puxando dados em ordem do menor para o maior
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 18206       18206  246269      G. Nugent   16
# 17743       17743  244752      J. Olstad   16
# 13293       13293  246594    H. Massengo   16
# 16081       16081  241552    J. Italiano   16
# 18166       18166  243621       N. Ayéva   16
# ...           ...     ...            ...  ...
# 12192       12192  208927   H. Sulaimani   41
# 10545       10545  140183    S. Narazaki   42
# 18183       18183   53748  K. Pilkington   44
# 17726       17726   51963      T. Warner   44
# 4741         4741  140029       O. Pérez   45
#
#                                                 Photo        Nationality  \
# 18206  https://cdn.sofifa.org/players/4/19/246269.png            England
# 17743  https://cdn.sofifa.org/players/4/19/244752.png             Norway
# 13293  https://cdn.sofifa.org/players/4/19/246594.png             France
# 16081  https://cdn.sofifa.org/players/4/19/241552.png          Australia
# ...

# %%
dados.sort_values('Name', ascending= False) # do maior para o menor
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 10002       10002  220433   Óscar Whalley   24
# 10353       10353  243558  Óscar Valentín   23
# 2564         2564  208621     Óscar Plano   27
# 9803         9803  229865    Óscar Pinchi   22
# 15334       15334  246284       Óscar Gil   20
# ...           ...     ...             ...  ...
# 12816       12816  245438   A. Abdu Jaber   21
# 6388         6388  138698         A. Abdi   31
# 3055         3055  198076    A. Abdennour   28
# 15665       15665  243896   A. Abdellaoui   25
# 13632       13632  228006        A. Abang   21
#
#                                                 Photo  Nationality  \
# 10002  https://cdn.sofifa.org/players/4/19/220433.png        Spain
# 10353  https://cdn.sofifa.org/players/4/19/243558.png        Spain
# 2564   https://cdn.sofifa.org/players/4/19/208621.png        Spain
# 9803   https://cdn.sofifa.org/players/4/19/229865.png        Spain
# ...

# %%
dados_xlss = pd.read_excel('fifa/data.xlsx')              # exemplo paraabrir um arquivo excel.

# %%
dados_txt = pd.read_csv('Fifa/data.txt', delimiter = '\t')

# %%
dados_html = pd.read_html('https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States#Presidents')          # listas de presidentes USA

#dados_html
# Out:
# [    No.[a]  Portrait                       Name (birth–death)  \
#  0        1       NaN       George Washington (1732–1799) [19]
#  1        2       NaN              John Adams (1735–1826) [21]
#  2        3       NaN        Thomas Jefferson (1743–1826) [23]
#  3        4       NaN           James Madison (1751–1836) [24]
#  4        5       NaN            James Monroe (1758–1831) [26]
#  5        6       NaN       John Quincy Adams (1767–1848) [27]
#  6        7       NaN          Andrew Jackson (1767–1845) [30]
#  7        8       NaN        Martin Van Buren (1782–1862) [31]
#  8        9       NaN  William Henry Harrison (1773–1841) [32]
#  9       10       NaN              John Tyler (1790–1862) [33]
#  10      11       NaN           James K. Polk (1795–1849) [36]
#  11      12       NaN          Zachary Taylor (1784–1850) [37]
#  12      13       NaN        Millard Fillmore (1800–1874) [38]
#  13      14       NaN         Franklin Pierce (1804–1869) [40]
# ...

# %%
dados ['Total'] = dados['Acceleration'] + dados['Agility'] + dados['Reactions']    # buscando por colunas  e somando para ver o melhor resukltado entre jogadores
dados
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
dados = dados[['Name', 'Total']]  # puxando pelo nome e total
dados
# Out:
#                      Name  Total
# 0                L. Messi  277.0
# 1       Cristiano Ronaldo  272.0
# 2               Neymar Jr  284.0
# 3                  De Gea  207.0
# 4            K. De Bruyne  248.0
# ...                   ...    ...
# 18202        J. Lundstram  163.0
# 18203  N. Christoffersson  119.0
# 18204           B. Worman  167.0
# 18205      D. Walker-Rice  134.0
# 18206           G. Nugent  163.0
#
# [18207 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dados['Total'].plot(kind='hist', bins=20, title='Total')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
dados.sort_values('Total', ascending= False)    # puxsndo coluna total do menor para o maior
# Out:
#                  Name  Total
# 2           Neymar Jr  284.0
# 5           E. Hazard  279.0
# 0            L. Messi  277.0
# 26           M. Salah  276.0
# 50         D. Mertens  275.0
# ...               ...    ...
# 13279    P. Mazzocchi    NaN
# 13280       Y. Ammour    NaN
# 13281  Jwa Joon Hyeop    NaN
# 13282      O. Marrufo    NaN
# 13283     Han Pengfei    NaN
#
# [18207 rows x 2 columns]

# %%
dados.to_csv('dados1.csv', index = False)   # criar um arquivo dados1.csv
# Out:
#   File "<ipython-input-22-2936ac212be4>", line 1
#     dados.to_csv('dados1.csv' index = false)
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
dados.to_excel('dados2.xlsx', index = False)  # criar um arquivo dados2.xlsx

# %%
dados.csv('dados3.txt', index = False, sep = '\t')  # criar um arquivo dados3.txt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-448d51f07566> in <cell line: 0>()
# ----> 1 dados.csv('dados3.txt', index = False, sep = '\t')  # criar um arquivo dados3.txt
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'csv'
