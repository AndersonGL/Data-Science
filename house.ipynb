# %% [markdown]
# <a href="https://colab.research.google.com/github/AndersonGL/Data-Science/blob/main/house.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd       # ANTES DE RODAR OS ARQUIVOS DA RUN NOS IMPORTS.
import re

# %%
df = pd.read_csv("house.csv")  

df
                                        # Abrindo o arquivo cvs
#df.head(6)    # 5 primeiros              # Print  (atentar com read e head)
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
filter1 =df.loc[df['Rooms'] == 3 & (df['Type'] == 'h') & (df['Price'] >= 300000)] 
filter1      # Filtrando linhas, unidades e valores dos imoveis
# Out:
#              Suburb              Address  Rooms Type      Price Method  \
# 193     Albert Park          9 Durham St      1    h   985000.0      S
# 400        Armadale        10 William St      1    h  1435000.0     SP
# 896          Balwyn  9/204 Whitehorse Rd      1    h   390000.0     VB
# 1812       Brighton         2a Roslyn St      1    h  1775000.0      S
# 2241      Brunswick           32 Rose St      1    h   800000.0     PI
# ...             ...                  ...    ...  ...        ...    ...
# 28300       Wollert       1 Kilwarrie St      1    h   376000.0     SP
# 30967       Emerald     80 Kilvington Dr      1    h   462000.0      S
# 31014       Newport       3/3 Jubilee St      1    h   340000.0     SP
# 32523       Carlton       164 Canning St      1    h  1252000.0      S
# 33095  Broadmeadows        14 Railway Cr      1    h   500000.0      S
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
# importou a modulo re (Regular expression)

filter2 = df.loc[df['Address'].str.contains('Turner st|Turner Rd', flags=re.I)] # ultilizando (str.contains) para filtra a string contains

filter2
# Out:
#              Suburb            Address  Rooms Type      Price Method  \
# 1        Abbotsford       85 Turner St      2    h  1480000.0      S
# 8        Abbotsford       53 Turner St      2    h        NaN      S
# 9        Abbotsford       99 Turner St      2    h        NaN      S
# 22       Abbotsford  106/119 Turner St      1    u   481000.0     SP
# 53       Abbotsford       31 Turner St      4    h  1542000.0      S
# 6453   Malvern East       16 Turner St      4    h        NaN      S
# 6857   Moonee Ponds     3/16 Turner St      2    u   550000.0     VB
# 6928   Moonee Ponds      4/6 Turner St      2    u   600000.0      S
# 20044       Highett       48 Turner Rd      2    h   832000.0      S
# 22496       Highett     3/15 Turner Rd      2    u   770000.0      S
# 23205       Highett      2/4 Turner Rd      2    u   680500.0      S
# 31905  Malvern East       24 Turner St      6    h  4700000.0      S
# 34461  Malvern East       27 Turner St      2    h  1040000.0      S
#
# ...

# %%
filter3 = df.loc[df['Address'].str.contains( '^59', flags=re.I) & (df['Price'] <= 500000)]

filter3
# Out:
#               Suburb          Address  Rooms Type     Price Method SellerG  \
# 9938   Sunshine West   59 Felstead Av      3    h  465000.0      S   Bells
# 29898        Sunbury  59 Davenport Dr      3    h  499500.0      S   Barry
#
#             Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 9938   7/11/2016      13.5    3020.0  ...       NaN  NaN       NaN
# 29898  6/01/2018      31.7    3429.0  ...       2.0  2.0     664.0
#
#        BuildingArea  YearBuilt            CouncilArea Lattitude  Longtitude  \
# 9938            NaN        NaN  Brimbank City Council       NaN         NaN
# 29898           NaN        NaN      Hume City Council -37.59034    144.7089
#
#                  Regionname Propertycount
# 9938   Western Metropolitan        6763.0
# 29898  Western Metropolitan       14092.0
#
# [2 rows x 21 columns]

# %%
df.loc[df['SellerG'] == 'Nelson']   # Puxando nome Nelson da coluna SelleG
# Out:
#            Suburb            Address  Rooms Type      Price Method SellerG  \
# 6      Abbotsford        55a Park St      4    h  1600000.0     VB  Nelson
# 7      Abbotsford       16 Maugie St      4    h        NaN     SN  Nelson
# 11     Abbotsford       124 Yarra St      3    h  1876000.0      S  Nelson
# 14     Abbotsford      98 Charles St      2    h  1636000.0      S  Nelson
# 24     Abbotsford    40 Nicholson St      3    h  1350000.0     VB  Nelson
# ...           ...                ...    ...  ...        ...    ...     ...
# 34790   Thornbury        111 Keon St      3    h  1605500.0      S  Nelson
# 34792   Thornbury  83/337 Station St      2    u        NaN      S  Nelson
# 34793   Thornbury        44 Wales St      3    h        NaN     SP  Nelson
# 34799  Travancore      37 Mooltan St      3    h        NaN      S  Nelson
# 34808    Viewbank       78 Graham Rd      3    h   900000.0     PI  Nelson
#
# ...

# %%
df.loc[df['SellerG'] == 'Nelson', 'SellerG' ]  = 'Jellis' # Trocando o nome da linha do SellerG para de Nelson para Jellis 

df
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
df.loc[df['SellerG'] == 'Jellis', ['Method'] ]  = 'Anderson' # Trocando a linha do (Method) de  SS para Anderson

df
# Out:
#            Suburb             Address  Rooms Type      Price    Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN  Anderson
# 1      Abbotsford        85 Turner St      2    h  1480000.0         S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0         S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN        VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0        SP
# ...           ...                 ...    ...  ...        ...       ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0        PI
# 34853  Yarraville       29A Murray St      2    h   888000.0        SP
# 34854  Yarraville      147A Severn St      2    t   705000.0         S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0        SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0        PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df.groupby(['SellerG']).mean(numeric_only=True) #  puxando media
# Out:
#                  Rooms         Price   Distance     Postcode  Bedroom2  \
# SellerG
# @Realty       3.666667  7.200455e+05  18.166667  3074.416667  3.571429
# A             3.000000           NaN  17.400000  3048.000000  3.000000
# AIME          4.000000  9.800000e+05  12.200000  3147.000000       NaN
# ASL           3.600000  1.227100e+06  12.080000  3086.200000  3.600000
# Abercromby's  3.244898  2.041424e+06   5.673469  3139.489796  3.421053
# ...                ...           ...        ...          ...       ...
# iOne          3.000000  6.200000e+05   7.000000  3013.000000  3.000000
# iProperty     3.000000  8.200000e+05  17.200000  3133.000000  3.000000
# iSell         3.062500  7.231600e+05  21.946875  3172.437500  3.100000
# iTRAK         3.363636  7.708935e+05  24.103030  3211.909091  3.344828
# voglwalpole   3.500000           NaN  20.600000  3134.500000  4.000000
#
#               Bathroom       Car     Landsize  BuildingArea    YearBuilt  \
# SellerG
# ...

# %%
df.groupby(['SellerG']).sum().sort_values('Price' , ascending= False).head(10) # lista dos 10 melhores vendedores
# Out:
#                                                           Suburb  \
# SellerG
# Jellis         AbbotsfordAbbotsfordAbbotsfordAbbotsfordAbbots...
# Marshall       AbbotsfordAlbert ParkAlbert ParkAlbert ParkAlb...
# Barry          Airport WestAirport WestAirport WestAirport We...
# hockingstuart  AbbotsfordAlbert ParkAlbert ParkAlbert ParkAlb...
# Buxton         Albert ParkAlbert ParkAltona NorthAshburtonAsh...
# Ray            Airport WestAirport WestArmadaleArmadaleArmada...
# Fletchers      ArmadaleAshburtonAshburtonAshburtonAshburtonAs...
# Biggin         AbbotsfordAbbotsfordAbbotsfordAbbotsfordAbbots...
# Woodards       Ascot ValeAscot ValeAscot ValeAshwoodAshwoodAs...
# RT             Albert ParkAlbert ParkAltona NorthAltona North...
#
#                                                          Address  Rooms  \
# SellerG
# Jellis         68 Studley St55a Park St16 Maugie St129 Charle...  19534
# Marshall       49 Park St14 Merton St75 Graham St104 Richards...   6746
# ...

# %%
df.groupby(['SellerG']).count() # puxando atraves de contagem
# Out:
#               Suburb  Address  Rooms  Type  Price  Method  Date  Distance  \
# SellerG
# @Realty           12       12     12    12     11      12    12        12
# A                  1        1      1     1      0       1     1         1
# AIME               1        1      1     1      1       1     1         1
# ASL                5        5      5     5      5       5     5         5
# Abercromby's      49       49     49    49     33      49    49        49
# ...              ...      ...    ...   ...    ...     ...   ...       ...
# iOne               1        1      1     1      1       1     1         1
# iProperty          1        1      1     1      1       1     1         1
# iSell             32       32     32    32     25      32    32        32
# iTRAK             33       33     33    33     31      33    33        33
# voglwalpole        2        2      2     2      0       2     2         2
#
# ...
